# %% [markdown]
# # Movement Clustering
# This notebook is part of the CASEFILE academic simulation.

# %%
from pathlib import Path
import sys
ROOT=Path.cwd().resolve().parents[0] if (Path.cwd()/'src').exists() else Path.cwd()
print('Project root:', ROOT)

# %%
from src.pipeline import load_data, preprocess, add_features
traj,cases=load_data()
df=add_features(preprocess(traj))
df.head()
